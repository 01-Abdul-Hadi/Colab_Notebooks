# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from pylab import rcParams
import matplotlib.pyplot as plt
import warnings
from mlxtend.plotting import plot_decision_regions
from matplotlib.colors import ListedColormap
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_circles
import seaborn as sns

# %%
X, y = make_circles(n_samples=100, noise=0.1, random_state=1)

# %%
sns.scatterplot(X[:,0],X[:,1],hue=y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-3dbc6f4a86c6> in <cell line: 1>()
# ----> 1 sns.scatterplot(X[:,0],X[:,1],hue=y)
#
# TypeError: scatterplot() takes from 0 to 1 positional arguments but 2 positional arguments (and 1 keyword-only argument) were given

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.20, random_state=2)

# %%
model = Sequential()
model.add(Dense(256, input_dim=2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam',
metrics=['accuracy'])
history = model.fit(X_train, y_train, validation_data=(X_test,
y_test), epochs=3500, verbose=0)
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
#plot_decision_regions(X_test, y_test.ravel(), clf = model, legend=2)
plt.show()

# %%
model = Sequential()
model.add(Dense(256, input_dim=2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam',
metrics=['accuracy'])
callback = EarlyStopping(
monitor="val_loss",
min_delta=0.00001,
patience=20,
verbose=1,
mode="auto",
baseline=None,
restore_best_weights=False
)
history = model.fit(X_train, y_train, validation_data=(X_test,
y_test), epochs=3500, callbacks=callback)
# Out:
# Epoch 1/3500
# 3/3 [==============================] - 2s 109ms/step - loss: 0.6927 - accuracy: 0.5000 - val_loss: 0.6940 - val_accuracy: 0.4500
# Epoch 2/3500
# 3/3 [==============================] - 0s 24ms/step - loss: 0.6901 - accuracy: 0.5000 - val_loss: 0.6954 - val_accuracy: 0.4500
# Epoch 3/3500
# 3/3 [==============================] - 0s 30ms/step - loss: 0.6887 - accuracy: 0.5000 - val_loss: 0.6955 - val_accuracy: 0.4000
# Epoch 4/3500
# 3/3 [==============================] - 0s 29ms/step - loss: 0.6875 - accuracy: 0.5125 - val_loss: 0.6970 - val_accuracy: 0.4500
# Epoch 5/3500
# 3/3 [==============================] - 0s 21ms/step - loss: 0.6865 - accuracy: 0.5375 - val_loss: 0.6987 - val_accuracy: 0.4500
# Epoch 6/3500
# 3/3 [==============================] - 0s 30ms/step - loss: 0.6860 - accuracy: 0.5250 - val_loss: 0.7007 - val_accuracy: 0.4500
# Epoch 7/3500
# 3/3 [==============================] - 0s 32ms/step - loss: 0.6848 - accuracy: 0.5500 - val_loss: 0.7019 - val_accuracy: 0.5000
# Epoch 8/3500
# 3/3 [==============================] - 0s 21ms/step - loss: 0.6840 - accuracy: 0.6125 - val_loss: 0.7033 - val_accuracy: 0.5500
# Epoch 9/3500
# 3/3 [==============================] - 0s 21ms/step - loss: 0.6831 - accuracy: 0.6375 - val_loss: 0.7052 - val_accuracy: 0.4000
# Epoch 10/3500
# 3/3 [==============================] - 0s 30ms/step - loss: 0.6823 - accuracy: 0.6125 - val_loss: 0.7072 - val_accuracy: 0.3000
# Epoch 11/3500
# 3/3 [==============================] - 0s 21ms/step - loss: 0.6816 - accuracy: 0.5625 - val_loss: 0.7090 - val_accuracy: 0.3000
# Epoch 12/3500
# 3/3 [==============================] - 0s 20ms/step - loss: 0.6812 - accuracy: 0.6000 - val_loss: 0.7103 - val_accuracy: 0.3500
# Epoch 13/3500
# 3/3 [==============================] - 0s 30ms/step - loss: 0.6803 - accuracy: 0.6000 - val_loss: 0.7114 - val_accuracy: 0.3000
# Epoch 14/3500
# 3/3 [==============================] - 0s 29ms/step - loss: 0.6797 - accuracy: 0.5875 - val_loss: 0.7118 - val_accuracy: 0.2500
# Epoch 15/3500
# 3/3 [==============================] - 0s 31ms/step - loss: 0.6790 - accuracy: 0.5875 - val_loss: 0.7120 - val_accuracy: 0.2500
# Epoch 16/3500
# 3/3 [==============================] - 0s 22ms/step - loss: 0.6784 - accuracy: 0.5875 - val_loss: 0.7126 - val_accuracy: 0.2500
# Epoch 17/3500
# 3/3 [==============================] - 0s 32ms/step - loss: 0.6776 - accuracy: 0.6000 - val_loss: 0.7135 - val_accuracy: 0.2500
# Epoch 18/3500
# 3/3 [==============================] - 0s 31ms/step - loss: 0.6771 - accuracy: 0.6125 - val_loss: 0.7147 - val_accuracy: 0.2500
# Epoch 19/3500
# 3/3 [==============================] - 0s 29ms/step - loss: 0.6763 - accuracy: 0.6125 - val_loss: 0.7154 - val_accuracy: 0.3500
# Epoch 20/3500
# 3/3 [==============================] - 0s 20ms/step - loss: 0.6759 - accuracy: 0.6125 - val_loss: 0.7170 - val_accuracy: 0.3500
# Epoch 21/3500
# 3/3 [==============================] - 0s 21ms/step - loss: 0.6751 - accuracy: 0.6000 - val_loss: 0.7180 - val_accuracy: 0.3500
# Epoch 21: early stopping

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
#plot_decision_regions(X_test, y_test.ravel(), clf = model, legend=2)
plt.show()
